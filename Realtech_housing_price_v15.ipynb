# %% [markdown]
# ### Step1: Importing the Necessary libraries and reading our data

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split  
import tensorflow 
from tensorflow import keras
from tensorflow.keras import layers 
from sklearn.linear_model import LinearRegression
from scipy import stats

# %%
df1 = pd.read_csv('california_housing_train.csv')
df2 = pd.read_csv('california_housing_test.csv')
frames = [df1,df2]
df = pd.concat(frames,ignore_index=True)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 19995    -119.86     34.42                23.0       1450.0           642.0
# 19996    -118.14     34.06                27.0       5257.0          1082.0
# 19997    -119.70     36.30                10.0        956.0           201.0
# 19998    -117.12     34.10                40.0         96.0            14.0
# 19999    -119.63     34.42                42.0       1765.0           263.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 19995      1258.0       607.0         1.1790            225000.0
# 19996      3496.0      1036.0         3.3906            237200.0
# 19997       693.0       220.0         2.2895             62000.0
# 19998        46.0        14.0         3.2708            162500.0
# 19999       753.0       260.0         8.5608            500001.0
#
# [20000 rows x 9 columns]

# %%
df.shape
# Out:
# (20000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20000 non-null  float64
#  1   latitude            20000 non-null  float64
#  2   housing_median_age  20000 non-null  float64
#  3   total_rooms         20000 non-null  float64
#  4   total_bedrooms      20000 non-null  float64
#  5   population          20000 non-null  float64
#  6   households          20000 non-null  float64
#  7   median_income       20000 non-null  float64
#  8   median_house_value  20000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# ### Step2: Data Cleaning
# #### Checking if our dataset has null or duplicated values or outliers

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x=df['median_house_value'])
# Out:
# <AxesSubplot:xlabel='median_house_value'>

# %% [markdown]
# #### We noticd we have outliers values so we need to Remove it from our dataset

# %%
df_outliers= df[(np.abs(stats.zscore(df['median_house_value'])) < 1)]
print(f'We will lose {((df.shape[0] - df_outliers.shape[0])/df.shape[0])*100}% of our data if we drop the outliers')
# Out:
# We will lose 29.885% of our data if we drop the outliers

# %%
df_outliers.shape
# Out:
# (14023, 9)

# %%
df_outliers
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16       -114.65     33.60                28.0       1678.0           322.0
# 25       -115.32     32.82                34.0        591.0           139.0
# 32       -115.39     32.76                16.0       1136.0           196.0
# 33       -115.40     32.86                19.0       1087.0           171.0
# 34       -115.40     32.70                19.0        583.0           113.0
# ...          ...       ...                 ...          ...             ...
# 19991    -117.17     34.28                13.0       4867.0           718.0
# 19994    -117.93     33.86                35.0        931.0           181.0
# 19995    -119.86     34.42                23.0       1450.0           642.0
# 19996    -118.14     34.06                27.0       5257.0          1082.0
# 19998    -117.12     34.10                40.0         96.0            14.0
#
#        population  households  median_income  median_house_value
# 16          666.0       256.0         2.9653             94900.0
# 25          327.0        89.0         3.6528            100000.0
# 32          481.0       185.0         6.2558            146300.0
# 33          649.0       173.0         3.3182            113800.0
# 34          531.0       134.0         1.6838             95800.0
# ...           ...         ...            ...                 ...
# 19991       780.0       250.0         7.1997            253800.0
# 19994       516.0       174.0         5.5867            182500.0
# 19995      1258.0       607.0         1.1790            225000.0
# 19996      3496.0      1036.0         3.3906            237200.0
# 19998        46.0        14.0         3.2708            162500.0
#
# [14023 rows x 9 columns]

# %%
sns.boxplot(x=df_outliers['median_house_value'])
# Out:
# <AxesSubplot:xlabel='median_house_value'>

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20000.000000  20000.000000        20000.000000  20000.000000
# mean    -119.566172     35.626750           28.627750   2637.051550
# std        2.003609      2.136141           12.582229   2176.314757
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1451.000000
# 50%     -118.490000     34.250000           29.000000   2126.000000
# 75%     -118.000000     37.710000           37.000000   3149.000000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20000.000000  20000.000000  20000.000000   20000.000000
# mean       537.991800   1425.557650    499.525450       3.872132
# std        420.631119   1131.048487    381.729517       1.900356
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    788.000000    280.000000       2.562500
# 50%        434.000000   1166.000000    409.000000       3.536000
# 75%        647.000000   1724.000000    604.000000       4.745325
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20000.000000
# mean        207082.716750
# std         115557.055856
# min          14999.000000
# 25%         119800.000000
# 50%         179800.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# ### Step3:  **Predictive Analysis**

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True).set_title("Heat Map for our Data")
# Out:
# Text(0.5, 1.0, 'Heat Map for our Data')

# %% [markdown]
# #### We noticed a strong correlation between "median_income" and "median_house_value"feature. We'll explore this features further.

# %%
plt.figure(figsize=(15,8))
ax= sns.scatterplot(data=df, x="median_income", y="median_house_value").set_title("Income And House Value Relationship")

# %%
plt.figure(figsize=(15,8))
ax= sns.scatterplot(data=df_outliers, x="median_income", y="median_house_value").set_title("Income And House Value Relationship after dropping outliers")

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df, x="longitude", y="latitude", hue=df["median_house_value"], size=df["median_house_value"]).set_title("longitude and latitude  relationship with house value")
# Out:
# Text(0.5, 1.0, 'longitude and latitude  relationship with house value')

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df_outliers, x="longitude", y="latitude", hue=df["median_house_value"], size=df["median_house_value"]).set_title("longitude and latitude  relationship with house value after dropping outliers")
# Out:
# Text(0.5, 1.0, 'longitude and latitude  relationship with house value after dropping outliers')

# %% [markdown]
# #### We noticed that there is a specific area where the price is high

# %% [markdown]
# # Step4: Modeling And Splitting Our Data

# %%
X1 = df.drop(columns=['median_house_value'])
X2 = df_outliers.drop(columns=['median_house_value'])
X1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 19995    -119.86     34.42                23.0       1450.0           642.0
# 19996    -118.14     34.06                27.0       5257.0          1082.0
# 19997    -119.70     36.30                10.0        956.0           201.0
# 19998    -117.12     34.10                40.0         96.0            14.0
# 19999    -119.63     34.42                42.0       1765.0           263.0
#
#        population  households  median_income
# 0          1015.0       472.0         1.4936
# 1          1129.0       463.0         1.8200
# 2           333.0       117.0         1.6509
# 3           515.0       226.0         3.1917
# 4           624.0       262.0         1.9250
# ...           ...         ...            ...
# 19995      1258.0       607.0         1.1790
# 19996      3496.0      1036.0         3.3906
# 19997       693.0       220.0         2.2895
# 19998        46.0        14.0         3.2708
# 19999       753.0       260.0         8.5608
#
# [20000 rows x 8 columns]

# %%
Y1 =df[['median_house_value']]
Y2 =df_outliers[['median_house_value']]
Y1
# Out:
#        median_house_value
# 0                 66900.0
# 1                 80100.0
# 2                 85700.0
# 3                 73400.0
# 4                 65500.0
# ...                   ...
# 19995            225000.0
# 19996            237200.0
# 19997             62000.0
# 19998            162500.0
# 19999            500001.0
#
# [20000 rows x 1 columns]

# %% [markdown]
# ### Splitting  the dataset into train and test set

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split( X1, Y1, train_size=0.7)
X_train2, X_test2, y_train2, y_test2 = train_test_split( X2, Y2, train_size=0.7)

# %%
input_shape= [X_train1.shape[1]]
input_shape
# Out:
# [8]

# %% [markdown]
# creating the model with 5 layers

# %%
model1 = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(200, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(200, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(200, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(200, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='relu')
           ])

#optimizer=keras.optimizers.RMSprop(0.001)
model1.compile(optimizer='adam',loss='mean_squared_error',metrics='mean_squared_error')

# %%
model1.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_33 (Bat  (None, 8)                32
#  chNormalization)
#
#  dense_124 (Dense)           (None, 200)               1800
#
#  batch_normalization_34 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_36 (Dropout)        (None, 200)               0
#
#  dense_125 (Dense)           (None, 200)               40200
#
#  batch_normalization_35 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_37 (Dropout)        (None, 200)               0
#
#  dense_126 (Dense)           (None, 200)               40200
#
#  batch_normalization_36 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_38 (Dropout)        (None, 200)               0
#
#  dense_127 (Dense)           (None, 200)               40200
#
#  batch_normalization_37 (Bat  (None, 200)              800
#  chNormalization)
#
#  dropout_39 (Dropout)        (None, 200)               0
#
#  dense_128 (Dense)           (None, 1)                 201
#
# =================================================================
# Total params: 125,833
# Trainable params: 124,217
# Non-trainable params: 1,616
# _________________________________________________________________

# %% [markdown]
# ### Fitting all train variables to the model

# %%
callback = tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3, min_delta=0.001, restore_best_weights=True )
history= model1.fit(X_train1,y_train1, validation_data=(X_test1, y_test1),epochs=500,batch_size=256, callbacks=[callback], verbose=0 )

# %%
history1_df= pd.DataFrame(history.history)
history1_df.loc[:, ['loss','val_loss']].plot();
print("Minimum validation loss: {}".format(history1_df['val_loss'].min()))
# Out:
# Minimum validation loss: 4464536576.0

# %% [markdown]
# mean squared error score

# %%
y_predict1= model1.predict(X_test1)

# %%
y_predict1
# Out:
# array([[150667.14],
#        [209329.06],
#        [167804.33],
#        ...,
#        [137825.56],
#        [250859.97],
#        [174082.53]], dtype=float32)

# %%
y_test1.values
# Out:
# array([[112500.],
#        [185600.],
#        [237500.],
#        ...,
#        [171300.],
#        [307200.],
#        [285500.]])

# %%
plt.figure(figsize=(15,8 ))
plt.scatter(y_test1.values, y_predict1)
plt.xlabel('True house value')
plt.ylabel('Predicted house value')
plt.title('Neural Network Model Without Removing Outliers Values ')
# Out:
# Text(0.5, 1.0, 'Neural Network Model Without Removing Outliers Values ')

# %% [markdown]
# ### Now we will create another model without outliers data to see if it's worthy to drop that rows

# %%
model2 = keras.Sequential()
model2.add(keras.layers.Dense(8, activation='relu', input_shape=(8,)))
model2.add(keras.layers.Dense(8, activation='relu'))
model2.add(keras.layers.Dense(4, activation='relu'))
model2.add(keras.layers.Dense(8, activation='relu'))
model2.add(keras.layers.Dense(1))
#optimizer=keras.optimizers.RMSprop(0.001)
model2.compile(optimizer='adam',loss='mean_squared_error',metrics='mean_squared_error')

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model2.fit(X_train2,y_train2,epochs=500,batch_size=20, callbacks=[callback])
# Out:
# Epoch 1/500
# 491/491 [==============================] - 1s 2ms/step - loss: 26294417408.0000 - mean_squared_error: 26294417408.0000
# Epoch 2/500
# 491/491 [==============================] - 1s 2ms/step - loss: 14364530688.0000 - mean_squared_error: 14364530688.0000
# Epoch 3/500
# 491/491 [==============================] - 1s 1ms/step - loss: 13860023296.0000 - mean_squared_error: 13860023296.0000
# Epoch 4/500
# 491/491 [==============================] - 1s 2ms/step - loss: 13384047616.0000 - mean_squared_error: 13384047616.0000
# Epoch 5/500
# 491/491 [==============================] - 1s 1ms/step - loss: 12819291136.0000 - mean_squared_error: 12819291136.0000
# Epoch 6/500
# 491/491 [==============================] - 1s 1ms/step - loss: 12172402688.0000 - mean_squared_error: 12172402688.0000
# Epoch 7/500
# 491/491 [==============================] - 1s 1ms/step - loss: 11351157760.0000 - mean_squared_error: 11351157760.0000
# Epoch 8/500
# 491/491 [==============================] - 1s 1ms/step - loss: 10207814656.0000 - mean_squared_error: 10207814656.0000
# Epoch 9/500
# 491/491 [==============================] - 1s 1ms/step - loss: 8562484224.0000 - mean_squared_error: 8562484224.0000
# Epoch 10/500
# 491/491 [==============================] - 1s 1ms/step - loss: 6607868416.0000 - mean_squared_error: 6607868416.0000
# Epoch 11/500
# 491/491 [==============================] - 1s 2ms/step - loss: 4658486272.0000 - mean_squared_error: 4658486272.0000
# Epoch 12/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3635269888.0000 - mean_squared_error: 3635269888.0000
# Epoch 13/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3432355328.0000 - mean_squared_error: 3432355328.0000
# Epoch 14/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3388147200.0000 - mean_squared_error: 3388147200.0000
# Epoch 15/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3369608704.0000 - mean_squared_error: 3369608704.0000
# Epoch 16/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3351599360.0000 - mean_squared_error: 3351599360.0000
# Epoch 17/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3347064576.0000 - mean_squared_error: 3347064576.0000
# Epoch 18/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3330395392.0000 - mean_squared_error: 3330395392.0000
# Epoch 19/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3328598016.0000 - mean_squared_error: 3328598016.0000
# Epoch 20/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3323247104.0000 - mean_squared_error: 3323247104.0000
# Epoch 21/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3312546048.0000 - mean_squared_error: 3312545536.0000
# Epoch 22/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3305157120.0000 - mean_squared_error: 3305157120.0000
# Epoch 23/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3292453376.0000 - mean_squared_error: 3292453376.0000
# Epoch 24/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3291799552.0000 - mean_squared_error: 3291799552.0000
# Epoch 25/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3279953152.0000 - mean_squared_error: 3279953152.0000
# Epoch 26/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3271441920.0000 - mean_squared_error: 3271441920.0000
# Epoch 27/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3270258176.0000 - mean_squared_error: 3270258176.0000
# Epoch 28/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3261794816.0000 - mean_squared_error: 3261794816.0000
# Epoch 29/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3255984128.0000 - mean_squared_error: 3255984128.0000
# Epoch 30/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3250286592.0000 - mean_squared_error: 3250286592.0000
# Epoch 31/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3244424192.0000 - mean_squared_error: 3244424192.0000
# Epoch 32/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3239179264.0000 - mean_squared_error: 3239179264.0000
# Epoch 33/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3225387520.0000 - mean_squared_error: 3225387520.0000
# Epoch 34/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3222756352.0000 - mean_squared_error: 3222756352.0000
# Epoch 35/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3217545984.0000 - mean_squared_error: 3217545984.0000
# Epoch 36/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3211647744.0000 - mean_squared_error: 3211647744.0000
# Epoch 37/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3204249600.0000 - mean_squared_error: 3204249600.0000
# Epoch 38/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3197002752.0000 - mean_squared_error: 3197003008.0000
# Epoch 39/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3186618112.0000 - mean_squared_error: 3186618112.0000
# Epoch 40/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3179068672.0000 - mean_squared_error: 3179068672.0000
# Epoch 41/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3175818496.0000 - mean_squared_error: 3175818496.0000
# Epoch 42/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3169551360.0000 - mean_squared_error: 3169551360.0000
# Epoch 43/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3160238336.0000 - mean_squared_error: 3160238336.0000
# Epoch 44/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3156227584.0000 - mean_squared_error: 3156227584.0000
# Epoch 45/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3150497280.0000 - mean_squared_error: 3150497280.0000
# Epoch 46/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3142841088.0000 - mean_squared_error: 3142841088.0000
# Epoch 47/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3133072128.0000 - mean_squared_error: 3133072128.0000
# Epoch 48/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3130525696.0000 - mean_squared_error: 3130525696.0000
# Epoch 49/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3119763712.0000 - mean_squared_error: 3119763712.0000
# Epoch 50/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3114477568.0000 - mean_squared_error: 3114477568.0000
# Epoch 51/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3111681024.0000 - mean_squared_error: 3111681024.0000
# Epoch 52/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3106716160.0000 - mean_squared_error: 3106716160.0000
# Epoch 53/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3091996416.0000 - mean_squared_error: 3091996416.0000
# Epoch 54/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3086780672.0000 - mean_squared_error: 3086780672.0000
# Epoch 55/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3076352256.0000 - mean_squared_error: 3076352256.0000
# Epoch 56/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3066120960.0000 - mean_squared_error: 3066120960.0000
# Epoch 57/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3063006720.0000 - mean_squared_error: 3063006720.0000
# Epoch 58/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3051089920.0000 - mean_squared_error: 3051089920.0000
# Epoch 59/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3039494656.0000 - mean_squared_error: 3039494656.0000
# Epoch 60/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3032771840.0000 - mean_squared_error: 3032771840.0000
# Epoch 61/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3025974784.0000 - mean_squared_error: 3025974784.0000
# Epoch 62/500
# 491/491 [==============================] - 1s 2ms/step - loss: 3017328128.0000 - mean_squared_error: 3017328128.0000
# Epoch 63/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3018328320.0000 - mean_squared_error: 3018328320.0000
# Epoch 64/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3010301184.0000 - mean_squared_error: 3010301184.0000
# Epoch 65/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2994577152.0000 - mean_squared_error: 2994577152.0000
# Epoch 66/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2990652928.0000 - mean_squared_error: 2990652928.0000
# Epoch 67/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2982787328.0000 - mean_squared_error: 2982787328.0000
# Epoch 68/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2969684736.0000 - mean_squared_error: 2969684736.0000
# Epoch 69/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2964204032.0000 - mean_squared_error: 2964204032.0000
# Epoch 70/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2966384640.0000 - mean_squared_error: 2966384640.0000
# Epoch 71/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2955848192.0000 - mean_squared_error: 2955848192.0000
# Epoch 72/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2940657664.0000 - mean_squared_error: 2940657664.0000
# Epoch 73/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2938378496.0000 - mean_squared_error: 2938378496.0000
# Epoch 74/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2924971264.0000 - mean_squared_error: 2924971264.0000
# Epoch 75/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2916726784.0000 - mean_squared_error: 2916726784.0000
# Epoch 76/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2908118528.0000 - mean_squared_error: 2908118528.0000
# Epoch 77/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2894807808.0000 - mean_squared_error: 2894807808.0000
# Epoch 78/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2894808832.0000 - mean_squared_error: 2894808832.0000
# Epoch 79/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2884562432.0000 - mean_squared_error: 2884562432.0000
# Epoch 80/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2885707008.0000 - mean_squared_error: 2885707008.0000
# Epoch 81/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2874201856.0000 - mean_squared_error: 2874201856.0000
# Epoch 82/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2859847168.0000 - mean_squared_error: 2859847168.0000
# Epoch 83/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2851503104.0000 - mean_squared_error: 2851503104.0000
# Epoch 84/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2844097792.0000 - mean_squared_error: 2844097792.0000
# Epoch 85/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2831592448.0000 - mean_squared_error: 2831592448.0000
# Epoch 86/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2829902592.0000 - mean_squared_error: 2829902592.0000
# Epoch 87/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2822253312.0000 - mean_squared_error: 2822252800.0000
# Epoch 88/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2806159360.0000 - mean_squared_error: 2806159360.0000
# Epoch 89/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2792801792.0000 - mean_squared_error: 2792801792.0000
# Epoch 90/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2790131712.0000 - mean_squared_error: 2790131712.0000
# Epoch 91/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2781251840.0000 - mean_squared_error: 2781251840.0000
# Epoch 92/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2763448320.0000 - mean_squared_error: 2763448320.0000
# Epoch 93/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2763992064.0000 - mean_squared_error: 2763992064.0000
# Epoch 94/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2745583872.0000 - mean_squared_error: 2745583872.0000
# Epoch 95/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2731338752.0000 - mean_squared_error: 2731338752.0000
# Epoch 96/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2719931904.0000 - mean_squared_error: 2719931904.0000
# Epoch 97/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2714327552.0000 - mean_squared_error: 2714327552.0000
# Epoch 98/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2705530880.0000 - mean_squared_error: 2705530880.0000
# Epoch 99/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2698402560.0000 - mean_squared_error: 2698402560.0000
# Epoch 100/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2688263936.0000 - mean_squared_error: 2688263936.0000
# Epoch 101/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2668048640.0000 - mean_squared_error: 2668048384.0000
# Epoch 102/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2659403264.0000 - mean_squared_error: 2659403264.0000
# Epoch 103/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2649556992.0000 - mean_squared_error: 2649556992.0000
# Epoch 104/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2640503808.0000 - mean_squared_error: 2640503808.0000
# Epoch 105/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2631918848.0000 - mean_squared_error: 2631918848.0000
# Epoch 106/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2611881728.0000 - mean_squared_error: 2611881728.0000
# Epoch 107/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2601323008.0000 - mean_squared_error: 2601323008.0000
# Epoch 108/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2589765120.0000 - mean_squared_error: 2589765120.0000
# Epoch 109/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2587671040.0000 - mean_squared_error: 2587671296.0000
# Epoch 110/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2569219840.0000 - mean_squared_error: 2569219840.0000
# Epoch 111/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2542599680.0000 - mean_squared_error: 2542599680.0000
# Epoch 112/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2544996352.0000 - mean_squared_error: 2544996352.0000
# Epoch 113/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2540471808.0000 - mean_squared_error: 2540471808.0000
# Epoch 114/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2515207424.0000 - mean_squared_error: 2515207424.0000
# Epoch 115/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2508758016.0000 - mean_squared_error: 2508758016.0000
# Epoch 116/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2493713664.0000 - mean_squared_error: 2493713664.0000
# Epoch 117/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2482719488.0000 - mean_squared_error: 2482719488.0000
# Epoch 118/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2482431232.0000 - mean_squared_error: 2482431232.0000
# Epoch 119/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2469918720.0000 - mean_squared_error: 2469918720.0000
# Epoch 120/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2453600256.0000 - mean_squared_error: 2453600256.0000
# Epoch 121/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2441942528.0000 - mean_squared_error: 2441942528.0000
# Epoch 122/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2431285504.0000 - mean_squared_error: 2431285504.0000
# Epoch 123/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2443558400.0000 - mean_squared_error: 2443558400.0000
# Epoch 124/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2406004736.0000 - mean_squared_error: 2406004736.0000
# Epoch 125/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2405084160.0000 - mean_squared_error: 2405084160.0000
# Epoch 126/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2399784704.0000 - mean_squared_error: 2399784704.0000
# Epoch 127/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2383596544.0000 - mean_squared_error: 2383596544.0000
# Epoch 128/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2367557376.0000 - mean_squared_error: 2367557376.0000
# Epoch 129/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2370425344.0000 - mean_squared_error: 2370425344.0000
# Epoch 130/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2361225728.0000 - mean_squared_error: 2361225728.0000
# Epoch 131/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2353530368.0000 - mean_squared_error: 2353530368.0000
# Epoch 132/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2339539456.0000 - mean_squared_error: 2339539456.0000
# Epoch 133/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2344427264.0000 - mean_squared_error: 2344427264.0000
# Epoch 134/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2325913344.0000 - mean_squared_error: 2325913344.0000
# Epoch 135/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2324766720.0000 - mean_squared_error: 2324766720.0000
# Epoch 136/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2320917504.0000 - mean_squared_error: 2320917504.0000
# Epoch 137/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2299238912.0000 - mean_squared_error: 2299238912.0000
# Epoch 138/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2302723328.0000 - mean_squared_error: 2302723328.0000
# Epoch 139/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2308033792.0000 - mean_squared_error: 2308033792.0000
# Epoch 140/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2289901824.0000 - mean_squared_error: 2289901824.0000
# Epoch 141/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2281946368.0000 - mean_squared_error: 2281946368.0000
# Epoch 142/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2277214720.0000 - mean_squared_error: 2277214720.0000
# Epoch 143/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2263330816.0000 - mean_squared_error: 2263330816.0000
# Epoch 144/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2273821440.0000 - mean_squared_error: 2273821440.0000
# Epoch 145/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2249357568.0000 - mean_squared_error: 2249357568.0000
# Epoch 146/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2249873408.0000 - mean_squared_error: 2249873408.0000
# Epoch 147/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2253886464.0000 - mean_squared_error: 2253886464.0000
# Epoch 148/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2243127808.0000 - mean_squared_error: 2243127808.0000
# Epoch 149/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2233206272.0000 - mean_squared_error: 2233206272.0000
# Epoch 150/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2232922112.0000 - mean_squared_error: 2232922112.0000
# Epoch 151/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2222000640.0000 - mean_squared_error: 2222000640.0000
# Epoch 152/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2221808896.0000 - mean_squared_error: 2221808896.0000
# Epoch 153/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2237005824.0000 - mean_squared_error: 2237005824.0000
# Epoch 154/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2220452352.0000 - mean_squared_error: 2220452352.0000
# Epoch 155/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2212115968.0000 - mean_squared_error: 2212115968.0000
# Epoch 156/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2215529472.0000 - mean_squared_error: 2215529472.0000
# Epoch 157/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2197302016.0000 - mean_squared_error: 2197302016.0000
# Epoch 158/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2202417408.0000 - mean_squared_error: 2202417408.0000
# Epoch 159/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2202985984.0000 - mean_squared_error: 2202985984.0000
# Epoch 160/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2192406016.0000 - mean_squared_error: 2192406016.0000
# Epoch 161/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2192351744.0000 - mean_squared_error: 2192351744.0000
# Epoch 162/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2207460352.0000 - mean_squared_error: 2207460352.0000
# Epoch 163/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2206238720.0000 - mean_squared_error: 2206238720.0000
# Epoch 164/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2179508480.0000 - mean_squared_error: 2179508480.0000
# Epoch 165/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2187885056.0000 - mean_squared_error: 2187884800.0000
# Epoch 166/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2182394880.0000 - mean_squared_error: 2182394880.0000
# Epoch 167/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2182689024.0000 - mean_squared_error: 2182689024.0000

# %%
y_predict2= model2.predict(X_test2)

# %%
y_predict2
# Out:
# array([[203390.98 ],
#        [197635.61 ],
#        [209953.92 ],
#        ...,
#        [172071.86 ],
#        [ 97169.164],
#        [154826.78 ]], dtype=float32)

# %%
y_test2.values
# Out:
# array([[237900.],
#        [198400.],
#        [288700.],
#        ...,
#        [222300.],
#        [ 97800.],
#        [169400.]])

# %%
plt.figure(figsize=(15,8 ))
plt.scatter(y_test2.values, y_predict2)
plt.xlabel('True house value')
plt.ylabel('Predicted house value')
plt.title('Neural Network Model with Removing Outliers Values ')
# Out:
# Text(0.5, 1.0, 'Neural Network Model with Removing Outliers Values ')

# %%
#splitting feature "median_income"'longitude','latitude' to train set , and put "median_house_value" to test set
#df_incomeX = df[['longitude','latitude','median_income']]
df_incomeX = df_outliers[['median_income']]
df_incomeY =df_outliers[['median_house_value']]
X_train3, X_test3, y_train3, y_test3 = train_test_split(df_incomeX,df_incomeY, train_size=0.7)

# %%
df_incomeX
# Out:
#        median_income
# 16            2.9653
# 25            3.6528
# 32            6.2558
# 33            3.3182
# 34            1.6838
# ...              ...
# 19991         7.1997
# 19994         5.5867
# 19995         1.1790
# 19996         3.3906
# 19998         3.2708
#
# [14023 rows x 1 columns]

# %% [markdown]
# creating the model with four layers

# %%
model3 = keras.Sequential()
model3.add(keras.layers.Dense(8, activation='relu', input_shape=(1,)))
model3.add(keras.layers.Dense(8, activation='relu'))
model3.add(keras.layers.Dense(4, activation='relu'))
model3.add(keras.layers.Dense(1))
#optimizer=keras.optimizers.RMSprop(0.001)
model3.compile(optimizer='adam',loss='mean_squared_error',metrics='mean_squared_error')

# %% [markdown]
# Fitting three Variables: median_income , longitude , latitude  to the model

# %%
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 8)                 16
#
#  dense_15 (Dense)            (None, 8)                 72
#
#  dense_16 (Dense)            (None, 4)                 36
#
#  dense_17 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 129
# Trainable params: 129
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model3.fit(X_train3,y_train3,epochs=500,batch_size=20, callbacks=[callback])
# Out:
# Epoch 1/500
# 491/491 [==============================] - 1s 1ms/step - loss: 37661343744.0000 - mean_squared_error: 37661343744.0000
# Epoch 2/500
# 491/491 [==============================] - 1s 1ms/step - loss: 37562793984.0000 - mean_squared_error: 37562793984.0000
# Epoch 3/500
# 491/491 [==============================] - 1s 1ms/step - loss: 37091454976.0000 - mean_squared_error: 37091454976.0000
# Epoch 4/500
# 491/491 [==============================] - 1s 2ms/step - loss: 35877130240.0000 - mean_squared_error: 35877130240.0000
# Epoch 5/500
# 491/491 [==============================] - 1s 2ms/step - loss: 33610461184.0000 - mean_squared_error: 33610461184.0000
# Epoch 6/500
# 491/491 [==============================] - 1s 1ms/step - loss: 30132727808.0000 - mean_squared_error: 30132727808.0000
# Epoch 7/500
# 491/491 [==============================] - 1s 1ms/step - loss: 25523099648.0000 - mean_squared_error: 25523099648.0000
# Epoch 8/500
# 491/491 [==============================] - 1s 1ms/step - loss: 20150167552.0000 - mean_squared_error: 20150167552.0000
# Epoch 9/500
# 491/491 [==============================] - 1s 1ms/step - loss: 14624362496.0000 - mean_squared_error: 14624362496.0000
# Epoch 10/500
# 491/491 [==============================] - 1s 1ms/step - loss: 9712584704.0000 - mean_squared_error: 9712584704.0000
# Epoch 11/500
# 491/491 [==============================] - 1s 1ms/step - loss: 6097979392.0000 - mean_squared_error: 6097979392.0000
# Epoch 12/500
# 491/491 [==============================] - 1s 1ms/step - loss: 4052075776.0000 - mean_squared_error: 4052075264.0000
# Epoch 13/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3254512896.0000 - mean_squared_error: 3254512896.0000
# Epoch 14/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3060433664.0000 - mean_squared_error: 3060433664.0000
# Epoch 15/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3029782528.0000 - mean_squared_error: 3029782528.0000
# Epoch 16/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3021824768.0000 - mean_squared_error: 3021824768.0000
# Epoch 17/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3014433536.0000 - mean_squared_error: 3014433792.0000
# Epoch 18/500
# 491/491 [==============================] - 1s 1ms/step - loss: 3006316544.0000 - mean_squared_error: 3006316544.0000
# Epoch 19/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2997527808.0000 - mean_squared_error: 2997527808.0000
# Epoch 20/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2988120064.0000 - mean_squared_error: 2988120064.0000
# Epoch 21/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2978853120.0000 - mean_squared_error: 2978853120.0000
# Epoch 22/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2968742912.0000 - mean_squared_error: 2968742912.0000
# Epoch 23/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2959162880.0000 - mean_squared_error: 2959162880.0000
# Epoch 24/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2949230336.0000 - mean_squared_error: 2949230336.0000
# Epoch 25/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2940426752.0000 - mean_squared_error: 2940426752.0000
# Epoch 26/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2930887424.0000 - mean_squared_error: 2930886912.0000
# Epoch 27/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2921488128.0000 - mean_squared_error: 2921488128.0000
# Epoch 28/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2912767744.0000 - mean_squared_error: 2912767744.0000
# Epoch 29/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2904409344.0000 - mean_squared_error: 2904409344.0000
# Epoch 30/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2895523584.0000 - mean_squared_error: 2895523584.0000
# Epoch 31/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2887409408.0000 - mean_squared_error: 2887409152.0000
# Epoch 32/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2878512128.0000 - mean_squared_error: 2878512128.0000
# Epoch 33/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2871216384.0000 - mean_squared_error: 2871216384.0000
# Epoch 34/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2862753024.0000 - mean_squared_error: 2862753024.0000
# Epoch 35/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2855159552.0000 - mean_squared_error: 2855159552.0000
# Epoch 36/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2847358208.0000 - mean_squared_error: 2847358208.0000
# Epoch 37/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2839779840.0000 - mean_squared_error: 2839779840.0000
# Epoch 38/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2832740864.0000 - mean_squared_error: 2832740864.0000
# Epoch 39/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2825511424.0000 - mean_squared_error: 2825511424.0000
# Epoch 40/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2818945024.0000 - mean_squared_error: 2818945024.0000
# Epoch 41/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2812309248.0000 - mean_squared_error: 2812309248.0000
# Epoch 42/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2805713152.0000 - mean_squared_error: 2805713152.0000
# Epoch 43/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2799932672.0000 - mean_squared_error: 2799932672.0000
# Epoch 44/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2793637888.0000 - mean_squared_error: 2793637888.0000
# Epoch 45/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2787461376.0000 - mean_squared_error: 2787461376.0000
# Epoch 46/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2781604864.0000 - mean_squared_error: 2781604864.0000
# Epoch 47/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2776104448.0000 - mean_squared_error: 2776104448.0000
# Epoch 48/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2770779392.0000 - mean_squared_error: 2770779392.0000
# Epoch 49/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2765001984.0000 - mean_squared_error: 2765001984.0000
# Epoch 50/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2759946240.0000 - mean_squared_error: 2759946240.0000
# Epoch 51/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2754495488.0000 - mean_squared_error: 2754495488.0000
# Epoch 52/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2750134016.0000 - mean_squared_error: 2750134016.0000
# Epoch 53/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2745431296.0000 - mean_squared_error: 2745431296.0000
# Epoch 54/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2740877568.0000 - mean_squared_error: 2740877568.0000
# Epoch 55/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2736326912.0000 - mean_squared_error: 2736326912.0000
# Epoch 56/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2732251648.0000 - mean_squared_error: 2732251648.0000
# Epoch 57/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2727975680.0000 - mean_squared_error: 2727975680.0000
# Epoch 58/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2723668224.0000 - mean_squared_error: 2723668224.0000
# Epoch 59/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2719687424.0000 - mean_squared_error: 2719687424.0000
# Epoch 60/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2715768064.0000 - mean_squared_error: 2715768064.0000
# Epoch 61/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2712032512.0000 - mean_squared_error: 2712032512.0000
# Epoch 62/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2708470016.0000 - mean_squared_error: 2708470016.0000
# Epoch 63/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2704527360.0000 - mean_squared_error: 2704527360.0000
# Epoch 64/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2701689344.0000 - mean_squared_error: 2701689344.0000
# Epoch 65/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2698036992.0000 - mean_squared_error: 2698036992.0000
# Epoch 66/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2695109376.0000 - mean_squared_error: 2695109376.0000
# Epoch 67/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2691732480.0000 - mean_squared_error: 2691732480.0000
# Epoch 68/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2688881408.0000 - mean_squared_error: 2688881408.0000
# Epoch 69/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2685893632.0000 - mean_squared_error: 2685893632.0000
# Epoch 70/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2682991104.0000 - mean_squared_error: 2682991104.0000
# Epoch 71/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2680440576.0000 - mean_squared_error: 2680440576.0000
# Epoch 72/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2677467136.0000 - mean_squared_error: 2677467136.0000
# Epoch 73/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2674880512.0000 - mean_squared_error: 2674880512.0000
# Epoch 74/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2672719872.0000 - mean_squared_error: 2672719616.0000
# Epoch 75/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2670445056.0000 - mean_squared_error: 2670445056.0000
# Epoch 76/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2667824640.0000 - mean_squared_error: 2667824640.0000
# Epoch 77/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2664897024.0000 - mean_squared_error: 2664897024.0000
# Epoch 78/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2663568896.0000 - mean_squared_error: 2663568896.0000
# Epoch 79/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2661203200.0000 - mean_squared_error: 2661203200.0000
# Epoch 80/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2659455232.0000 - mean_squared_error: 2659455232.0000
# Epoch 81/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2657643008.0000 - mean_squared_error: 2657643008.0000
# Epoch 82/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2655685632.0000 - mean_squared_error: 2655685632.0000
# Epoch 83/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2654146304.0000 - mean_squared_error: 2654146304.0000
# Epoch 84/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2651684864.0000 - mean_squared_error: 2651684864.0000
# Epoch 85/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2650557184.0000 - mean_squared_error: 2650557184.0000
# Epoch 86/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2648967424.0000 - mean_squared_error: 2648967424.0000
# Epoch 87/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2647141376.0000 - mean_squared_error: 2647141376.0000
# Epoch 88/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2645554944.0000 - mean_squared_error: 2645554944.0000
# Epoch 89/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2643960320.0000 - mean_squared_error: 2643960320.0000
# Epoch 90/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2643347200.0000 - mean_squared_error: 2643347200.0000
# Epoch 91/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2641613056.0000 - mean_squared_error: 2641613056.0000
# Epoch 92/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2640451328.0000 - mean_squared_error: 2640451328.0000
# Epoch 93/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2639284992.0000 - mean_squared_error: 2639284992.0000
# Epoch 94/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2638088704.0000 - mean_squared_error: 2638088704.0000
# Epoch 95/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2637255680.0000 - mean_squared_error: 2637255680.0000
# Epoch 96/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2636429824.0000 - mean_squared_error: 2636429824.0000
# Epoch 97/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2634780160.0000 - mean_squared_error: 2634780160.0000
# Epoch 98/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2633848832.0000 - mean_squared_error: 2633848832.0000
# Epoch 99/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2632995584.0000 - mean_squared_error: 2632995584.0000
# Epoch 100/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2632257280.0000 - mean_squared_error: 2632257280.0000
# Epoch 101/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2631249664.0000 - mean_squared_error: 2631249664.0000
# Epoch 102/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2630060288.0000 - mean_squared_error: 2630060288.0000
# Epoch 103/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2629820416.0000 - mean_squared_error: 2629820416.0000
# Epoch 104/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2628982016.0000 - mean_squared_error: 2628982016.0000
# Epoch 105/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2628147712.0000 - mean_squared_error: 2628147712.0000
# Epoch 106/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2626949632.0000 - mean_squared_error: 2626949632.0000
# Epoch 107/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2627082496.0000 - mean_squared_error: 2627082496.0000
# Epoch 108/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2625997568.0000 - mean_squared_error: 2625997568.0000
# Epoch 109/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2625461760.0000 - mean_squared_error: 2625461760.0000
# Epoch 110/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2625048832.0000 - mean_squared_error: 2625048832.0000
# Epoch 111/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2624272896.0000 - mean_squared_error: 2624272896.0000
# Epoch 112/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2623969536.0000 - mean_squared_error: 2623969536.0000
# Epoch 113/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2623120896.0000 - mean_squared_error: 2623120896.0000
# Epoch 114/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2623350528.0000 - mean_squared_error: 2623350528.0000
# Epoch 115/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2622360320.0000 - mean_squared_error: 2622360320.0000
# Epoch 116/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2621439488.0000 - mean_squared_error: 2621439232.0000
# Epoch 117/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2621638144.0000 - mean_squared_error: 2621638144.0000
# Epoch 118/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2621106176.0000 - mean_squared_error: 2621106176.0000
# Epoch 119/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2620520960.0000 - mean_squared_error: 2620520960.0000
# Epoch 120/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2620230912.0000 - mean_squared_error: 2620230912.0000
# Epoch 121/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2619991552.0000 - mean_squared_error: 2619991552.0000
# Epoch 122/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2619492352.0000 - mean_squared_error: 2619492608.0000
# Epoch 123/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2619075840.0000 - mean_squared_error: 2619075840.0000
# Epoch 124/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2618755328.0000 - mean_squared_error: 2618755328.0000
# Epoch 125/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2618679040.0000 - mean_squared_error: 2618679040.0000
# Epoch 126/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2617644544.0000 - mean_squared_error: 2617644544.0000
# Epoch 127/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2618384896.0000 - mean_squared_error: 2618384896.0000
# Epoch 128/500
# 491/491 [==============================] - 1s 1ms/step - loss: 2618137344.0000 - mean_squared_error: 2618137344.0000
# Epoch 129/500
# 491/491 [==============================] - 1s 2ms/step - loss: 2618021632.0000 - mean_squared_error: 2618021632.0000

# %% [markdown]
# mean squared error score

# %%
y_predict3= model3.predict(X_test3)

# %%
y_predict3
# Out:
# array([[198584.34],
#        [179473.61],
#        [185912.05],
#        ...,
#        [185151.2 ],
#        [219805.48],
#        [167063.2 ]], dtype=float32)

# %%
y_test3.values
# Out:
# array([[271300.],
#        [121400.],
#        [167600.],
#        ...,
#        [215300.],
#        [220000.],
#        [ 92200.]])

# %%
plt.figure(figsize=(15,8 ))
plt.scatter(y_test3.values, y_predict3)
plt.xlabel('True house value')
plt.ylabel('Predicted house value')
plt.title('Neural Network Model using "Income" Column')
# Out:
# Text(0.5, 1.0, 'Neural Network Model using "Income" Column')

# %% [markdown]
# ### we can save our model by using this code

# %%
#model2.save('Realtech_housing_prise.h5')

# %%
# if you want to load the model use this
#old_model = keras.models.load_model('Realtech_housing_prise.h5')

# %% [markdown]
# ## this has a beter result but still not that great so we go with LinearRegression

# %% [markdown]
# # LinearRegression

# %% [markdown]
# LinearRegression for all the data

# %%
reg = LinearRegression()
reg.fit(X_train1,y_train1)
reg_predict1= reg.predict(X_test1)
mean_squared_error(y_test1.values, reg_predict1)
# Out:
# 4953373520.951479

# %%
plt.figure(figsize=(15,8 ))
plt.scatter(y_test1.values, reg_predict1)
plt.xlabel('True house value')
plt.ylabel('Predicted house value')
plt.title('Linear Regression Model Without Removing Outliers Values')
# Out:
# Text(0.5, 1.0, 'Linear Regression Model Without Removing Outliers Values')

# %% [markdown]
# LinearRegression for only the median_income

# %%
reg2 = LinearRegression()
reg2.fit(X_train3,y_train3)
reg_predict2= reg2.predict(X_test3)
mean_squared_error(y_test3.values,reg_predict2)
# Out:
# 2643044982.8131022

# %%
plt.figure(figsize=(15,8 ))
plt.scatter(y_test3.values, reg_predict2)
plt.xlabel('True house value')
plt.ylabel('Predicted house value')
plt.title('Linear Regression Model using "income" Column Only')
# Out:
# Text(0.5, 1.0, 'Linear Regression Model using "income" Column Only')

# %% [markdown]
# LinearRegression for all data after dropping outliers

# %%
reg3 = LinearRegression()
reg3.fit(X_train2,y_train2)
reg_predict3= reg3.predict(X_test2)
mean_squared_error(y_test2.values,reg_predict3)
# Out:
# 1950226875.577495

# %%
plt.figure(figsize=(15,8 ))
plt.scatter(y_test2.values, reg_predict3)
plt.xlabel('True house value')
plt.ylabel('Predicted house value')
plt.title('Linear Regression Model With Removing Outliers Values')
# Out:
# Text(0.5, 1.0, 'Linear Regression Model With Removing Outliers Values')

# %%
# = keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Realtech_housing_prise/Realtech_housing_prise.h5')

# %%
#df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Realtech_housing_prise/california_housing_test.csv')

# %%
#o = df_test.drop(columns=['median_house_value'])
#p =df_test[['median_house_value']]
